# %%
import math
import torch
import gpytorch
from matplotlib import pyplot as plt

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# Training data is 100 points in [0,1] inclusive regularly spaced
train_x = torch.linspace(0, 1, 100)
# True function is sin(2*pi*x) with Gaussian noise
train_y = torch.sin(train_x * (2 * math.pi)) + torch.randn(train_x.size()) * math.sqrt(0.04)

train_x
# Out:
# tensor([0.0000, 0.0101, 0.0202, 0.0303, 0.0404, 0.0505, 0.0606, 0.0707, 0.0808,
#         0.0909, 0.1010, 0.1111, 0.1212, 0.1313, 0.1414, 0.1515, 0.1616, 0.1717,
#         0.1818, 0.1919, 0.2020, 0.2121, 0.2222, 0.2323, 0.2424, 0.2525, 0.2626,
#         0.2727, 0.2828, 0.2929, 0.3030, 0.3131, 0.3232, 0.3333, 0.3434, 0.3535,
#         0.3636, 0.3737, 0.3838, 0.3939, 0.4040, 0.4141, 0.4242, 0.4343, 0.4444,
#         0.4545, 0.4646, 0.4747, 0.4848, 0.4949, 0.5051, 0.5152, 0.5253, 0.5354,
#         0.5455, 0.5556, 0.5657, 0.5758, 0.5859, 0.5960, 0.6061, 0.6162, 0.6263,
#         0.6364, 0.6465, 0.6566, 0.6667, 0.6768, 0.6869, 0.6970, 0.7071, 0.7172,
#         0.7273, 0.7374, 0.7475, 0.7576, 0.7677, 0.7778, 0.7879, 0.7980, 0.8081,
#         0.8182, 0.8283, 0.8384, 0.8485, 0.8586, 0.8687, 0.8788, 0.8889, 0.8990,
#         0.9091, 0.9192, 0.9293, 0.9394, 0.9495, 0.9596, 0.9697, 0.9798, 0.9899,
#         1.0000])

# %%
train_y
# Out:
# tensor([-0.1589, -0.2231,  0.0655,  0.2015,  0.2531,  0.2803,  0.1842,  0.5668,
#          0.3941,  0.2282,  0.5097,  0.8463,  0.7620,  0.6208,  0.5592,  0.6833,
#          0.6384,  1.0582,  0.8455,  0.9792,  1.0316,  1.1523,  0.9370,  0.7753,
#          1.1810,  0.9688,  1.2246,  1.2743,  0.9304,  0.4922,  0.9265,  0.6631,
#          0.8581,  1.0012,  0.8164,  0.6785,  0.4755,  0.9827,  0.4261,  0.6789,
#          0.5010,  0.9472,  0.0522,  0.2171,  0.2907,  0.5677,  0.0808,  0.2216,
#          0.3302,  0.3234,  0.0180, -0.1469, -0.6006, -0.3014, -0.0859, -0.0971,
#         -0.1916, -0.3803, -0.5384, -0.7124, -0.4979, -0.8275, -0.6318, -0.7813,
#         -0.8575, -0.5795, -1.0447, -0.9038, -0.8531, -0.9832, -1.0199, -0.7137,
#         -1.3598, -1.0437, -0.6895, -1.0104, -0.7552, -1.3821, -0.8958, -0.9237,
#         -0.9708, -1.2636, -0.7577, -0.7668, -1.1705, -0.8080, -0.8642, -0.4678,
#         -0.4369, -0.4017, -0.3655, -0.4136, -0.4837, -0.2742, -0.4294, -0.2874,
#         -0.3669, -0.1705,  0.0145, -0.2361])
